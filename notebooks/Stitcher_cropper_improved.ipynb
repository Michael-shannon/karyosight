# %%
import sys
sys.path.append(r"D:\GITHUB_SOFTWARE\karyosight\karyosight\src")
from karyosight.stitcher import Stitcher
import karyosight.config as cfg

# 1. Import and instantiate
from karyosight.cropper import Cropper
from karyosight.visualization import plot_full_and_subgrid, plot_subgrid_layout
from pathlib import Path
# import config as cfg
# Out:
# d:\GITHUB_SOFTWARE\mamba_envs\karyosight-env\Lib\site-packages\dask\array\image.py:7: FutureWarning: `find_available_plugins` is deprecated since version 0.25 and will be removed in version 0.27. The plugin infrastructure of `skimage.io` is deprecated. Instead, use `imageio` or other I/O packages directly.
#   from skimage.io import imread as sk_imread
# d:\GITHUB_SOFTWARE\mamba_envs\karyosight-env\Lib\importlib\__init__.py:90: FutureWarning: `reset_plugins` is deprecated since version 0.25 and will be removed in version 0.27. The plugin infrastructure of `skimage.io` is deprecated. Instead, use `imageio` or other I/O packages directly.
#   return _bootstrap._gcd_import(name[level:], package, level)
# d:\GITHUB_SOFTWARE\mamba_envs\karyosight-env\Lib\site-packages\pydantic\_migration.py:283: UserWarning: `pydantic.error_wrappers:ValidationError` has been moved to `pydantic:ValidationError`.
#   warnings.warn(f'`{import_path}` has been moved to `{new_location}`.')

# %% [markdown]
# Stitcher

# %%
# ────────────────────────────────────────────────────────────────────
# Toggle here: True = split into sub-grids; False = one full grid
USE_SUBGRID = True
# ────────────────────────────────────────────────────────────────────

import sys, os
sys.path.append(r"D:\GITHUB_SOFTWARE\karyosight\karyosight\src")

from karyosight.stitcher import Stitcher
import karyosight.config as cfg
import matplotlib.pyplot as plt
from multiview_stitcher import vis_utils
from karyosight.visualization import plot_subgrid_layout, plot_full_and_subgrid

# ────────────────────────────────────────────────────────────────────
# Your existing configuration
cfg.BATCH_GRID_SHAPE   = (6, 6)
cfg.BATCH_TILE_OVERLAP = 1
cfg.IMAGE_LOADER       = 'tif'
# ────────────────────────────────────────────────────────────────────

# Initialize stitcher and scale dict once
st    = Stitcher(cfg.RAW_DIR)
scale = {"x": cfg.PIXEL_SIZE_X, "y": cfg.PIXEL_SIZE_Y, "z": cfg.PIXEL_SIZE_Z}

for cond in st.conditions:
    print(f"\n=== {cond.name} ===")
    full_meta = st.extract_metadata(cond)
    groups    = st.group_tiles_by_prefix(full_meta)

    for prefix, tiles in groups.items():
        print(f"\n── Grid {prefix}: {len(tiles)} tiles ──")

        # Build gm either as multiple sub-grids or one full-grid
        if USE_SUBGRID:
            gm = st.build_dynamic_group_meta(full_meta, tiles, prefix, cond)
            ax = plot_subgrid_layout(st, gm, scale)
            ax.set_title(f"{prefix} sub-grids")
            plt.show()
        else:
            cols = full_meta["grid_size"]["cols"]
            rows = full_meta["grid_size"]["rows"]
            gm = {
                **full_meta,
                "subgrids": [
                    {
                        "id":      f"{prefix}_full",
                        "tiles":   tiles,
                        "x_range": (0, cols),
                        "y_range": (0, rows),
                    }
                ]
            }

        # Run the same stitching loop on gm["subgrids"]
        for sg in gm["subgrids"]:
            print(f" • {sg['id']} — {len(sg['tiles'])} tiles")

            # Optional visual debug for sub-grids
            if USE_SUBGRID:
                ax = plot_full_and_subgrid(st, full_meta, scale, sg)
                ax.set_title(sg["id"])
                plt.show()

            # Compute translations for this window (or full grid)
            trans = st.compute_translations({**gm, "tiles": sg["tiles"]}, scale)

            # Convert to Zarr & load the MSIMs
            zarr_paths, msims = st.convert_tiles_to_zarr(
                tiles=sg["tiles"],
                tif_folder=cond,
                scale=scale,
                translations=trans,
                tile_shape=gm["tile_shape"],
                subgrid_id=sg["id"],
                overwrite=True,
                use_gpu=True,
            )

            # Optional MV-Stitcher preview of positions
            fig, ax = vis_utils.plot_positions(
                msims,
                use_positional_colors=True,
                transform_key="affine_metadata",
            )
            ax.set_title(sg["id"])
            plt.show()

            # Optional channel alignment
            msims, key = st.perform_channel_alignment(msims, do_align=False)

            # Tile-to-tile registration
            params, fk = st.stitch_tiles(msims, key, scheduler="threads")

            # Fuse & export
            out_dir = cfg.STITCHED_DIR / cond.name / prefix / sg["id"]
            os.makedirs(out_dir, exist_ok=True)




            # Enable z-cropping for this session
            cfg.CROP_Z_BLACK_FRAMES = False
            cfg.Z_CROP_THRESHOLD = 0.005  # 1% of global max intensity

            print(f"Z-cropping enabled: {cfg.CROP_Z_BLACK_FRAMES}")
            print(f"Threshold: {cfg.Z_CROP_THRESHOLD} (empty slices below {cfg.Z_CROP_THRESHOLD*100}% of max intensity)")

            # Now when you call st.fuse_and_export(), add the parameters:
            st.fuse_and_export(
                msims, 
                out_dir, 
                export_tiff=True,
                crop_z_black_frames=cfg.CROP_Z_BLACK_FRAMES,
                z_crop_threshold=cfg.Z_CROP_THRESHOLD
            )
            # st.fuse_and_export(msims, out_dir, export_tiff=False) #old one
            print(f"→ Written to {out_dir}")
# Out:
# === Condition_D50T50 ===
#
# ── Grid LB_diplarge_tetlarge_true_A01_G003: 320 tiles ──
#  • LB_diplarge_tetlarge_true_A01_G003_sg0_0 — 36 tiles
# → [Subgrid LB_diplarge_tetlarge_true_A01_G003_sg0_0] writing 36 tiles to D:\Lungbud_testsetmaster\analyze\Condition_D50T50
#    • Reading LB_diplarge_tetlarge_true_A01_G003_0001.tif for subgrid LB_diplarge_tetlarge_true_A01_G003_sg0_0
#    • Reading LB_diplarge_tetlarge_true_A01_G003_0002.tif for subgrid LB_diplarge_tetlarge_true_A01_G003_sg0_0
#    • Reading LB_diplarge_tetlarge_true_A01_G003_0003.tif for subgrid LB_diplarge_tetlarge_true_A01_G003_sg0_0
#    • Reading LB_diplarge_tetlarge_true_A01_G003_0004.tif for subgrid LB_diplarge_tetlarge_true_A01_G003_sg0_0
#    • Reading LB_diplarge_tetlarge_true_A01_G003_0005.tif for subgrid LB_diplarge_tetlarge_true_A01_G003_sg0_0
#    • Reading LB_diplarge_tetlarge_true_A01_G003_0006.tif for subgrid LB_diplarge_tetlarge_true_A01_G003_sg0_0
#    • Reading LB_diplarge_tetlarge_true_A01_G003_0032.tif for subgrid LB_diplarge_tetlarge_true_A01_G003_sg0_0
#    • Reading LB_diplarge_tetlarge_true_A01_G003_0031.tif for subgrid LB_diplarge_tetlarge_true_A01_G003_sg0_0
#    • Reading LB_diplarge_tetlarge_true_A01_G003_0030.tif for subgrid LB_diplarge_tetlarge_true_A01_G003_sg0_0
#    • Reading LB_diplarge_tetlarge_true_A01_G003_0029.tif for subgrid LB_diplarge_tetlarge_true_A01_G003_sg0_0
#    • Reading LB_diplarge_tetlarge_true_A01_G003_0028.tif for subgrid LB_diplarge_tetlarge_true_A01_G003_sg0_0
#    • Reading LB_diplarge_tetlarge_true_A01_G003_0027.tif for subgrid LB_diplarge_tetlarge_true_A01_G003_sg0_0
#    • Reading LB_diplarge_tetlarge_true_A01_G003_0033.tif for subgrid LB_diplarge_tetlarge_true_A01_G003_sg0_0
#    • Reading LB_diplarge_tetlarge_true_A01_G003_0034.tif for subgrid LB_diplarge_tetlarge_true_A01_G003_sg0_0
#    • Reading LB_diplarge_tetlarge_true_A01_G003_0035.tif for subgrid LB_diplarge_tetlarge_true_A01_G003_sg0_0
#    • Reading LB_diplarge_tetlarge_true_A01_G003_0036.tif for subgrid LB_diplarge_tetlarge_true_A01_G003_sg0_0
#    • Reading LB_diplarge_tetlarge_true_A01_G003_0037.tif for subgrid LB_diplarge_tetlarge_true_A01_G003_sg0_0
#    • Reading LB_diplarge_tetlarge_true_A01_G003_0038.tif for subgrid LB_diplarge_tetlarge_true_A01_G003_sg0_0
#    • Reading LB_diplarge_tetlarge_true_A01_G003_0064.tif for subgrid LB_diplarge_tetlarge_true_A01_G003_sg0_0
#    • Reading LB_diplarge_tetlarge_true_A01_G003_0063.tif for subgrid LB_diplarge_tetlarge_true_A01_G003_sg0_0
#    • Reading LB_diplarge_tetlarge_true_A01_G003_0062.tif for subgrid LB_diplarge_tetlarge_true_A01_G003_sg0_0
#    • Reading LB_diplarge_tetlarge_true_A01_G003_0061.tif for subgrid LB_diplarge_tetlarge_true_A01_G003_sg0_0
#    • Reading LB_diplarge_tetlarge_true_A01_G003_0060.tif for subgrid LB_diplarge_tetlarge_true_A01_G003_sg0_0
#    • Reading LB_diplarge_tetlarge_true_A01_G003_0059.tif for subgrid LB_diplarge_tetlarge_true_A01_G003_sg0_0
#    • Reading LB_diplarge_tetlarge_true_A01_G003_0065.tif for subgrid LB_diplarge_tetlarge_true_A01_G003_sg0_0
#    • Reading LB_diplarge_tetlarge_true_A01_G003_0066.tif for subgrid LB_diplarge_tetlarge_true_A01_G003_sg0_0
#    • Reading LB_diplarge_tetlarge_true_A01_G003_0067.tif for subgrid LB_diplarge_tetlarge_true_A01_G003_sg0_0
#    • Reading LB_diplarge_tetlarge_true_A01_G003_0068.tif for subgrid LB_diplarge_tetlarge_true_A01_G003_sg0_0
#    • Reading LB_diplarge_tetlarge_true_A01_G003_0069.tif for subgrid LB_diplarge_tetlarge_true_A01_G003_sg0_0
#    • Reading LB_diplarge_tetlarge_true_A01_G003_0070.tif for subgrid LB_diplarge_tetlarge_true_A01_G003_sg0_0
#    • Reading LB_diplarge_tetlarge_true_A01_G003_0096.tif for subgrid LB_diplarge_tetlarge_true_A01_G003_sg0_0
#    • Reading LB_diplarge_tetlarge_true_A01_G003_0095.tif for subgrid LB_diplarge_tetlarge_true_A01_G003_sg0_0
#    • Reading LB_diplarge_tetlarge_true_A01_G003_0094.tif for subgrid LB_diplarge_tetlarge_true_A01_G003_sg0_0
#    • Reading LB_diplarge_tetlarge_true_A01_G003_0093.tif for subgrid LB_diplarge_tetlarge_true_A01_G003_sg0_0
#    • Reading LB_diplarge_tetlarge_true_A01_G003_0092.tif for subgrid LB_diplarge_tetlarge_true_A01_G003_sg0_0
#    • Reading LB_diplarge_tetlarge_true_A01_G003_0091.tif for subgrid LB_diplarge_tetlarge_true_A01_G003_sg0_0
# [########################################] | 100% Completed | 2.55 ss
# [########################################] | 100% Completed | 22.74 ss
# [########################################] | 100% Completed | 13.04 ss
# [########################################] | 100% Completed | 7.08 sms
# [########################################] | 100% Completed | 17.31 ss
# [########################################] | 100% Completed | 10.71 ss
# [########################################] | 100% Completed | 18.00 ss
# [########################################] | 100% Completed | 20.64 ss
# [########################################] | 100% Completed | 20.71 ss
# [########################################] | 100% Completed | 13.84 ss
# [########################################] | 100% Completed | 12.43 ss
# [########################################] | 100% Completed | 21.74 ss
# [########################################] | 100% Completed | 20.81 ss
# [########################################] | 100% Completed | 20.61 ss
# [########################################] | 100% Completed | 28.72 ss
# [########################################] | 100% Completed | 18.50 ss
# [########################################] | 100% Completed | 13.95 ss
# [########################################] | 100% Completed | 9.21 sms
# [########################################] | 100% Completed | 22.04 ss
# [########################################] | 100% Completed | 19.71 ss
# [########################################] | 100% Completed | 26.38 ss
# [########################################] | 100% Completed | 17.60 ss
# [########################################] | 100% Completed | 10.63 ss
# [########################################] | 100% Completed | 19.00 ss
# [########################################] | 100% Completed | 14.96 ss
# [########################################] | 100% Completed | 18.50 ss
# [########################################] | 100% Completed | 15.18 ss
# [########################################] | 100% Completed | 18.32 ss
# [########################################] | 100% Completed | 22.75 ss
# [########################################] | 100% Completed | 20.85 ss
# [########################################] | 100% Completed | 23.66 ss
# [########################################] | 100% Completed | 25.08 ss
# [########################################] | 100% Completed | 22.34 ss
# [########################################] | 100% Completed | 16.08 ss
# [########################################] | 100% Completed | 24.26 ss
# [########################################] | 100% Completed | 20.22 ss
# [########################################] | 100% Completed | 21.84 ss
# [########################################] | 100% Completed | 18.11 ss
# [########################################] | 100% Completed | 22.87 ss
# [########################################] | 100% Completed | 17.40 ss
# [########################################] | 100% Completed | 28.36 ss
# [########################################] | 100% Completed | 12.45 ss
# [########################################] | 100% Completed | 29.97 ss
# [########################################] | 100% Completed | 23.58 ss
# [########################################] | 100% Completed | 14.37 ss
# [########################################] | 100% Completed | 28.34 ss
# [########################################] | 100% Completed | 18.63 ss
# [########################################] | 100% Completed | 27.12 ss
# [########################################] | 100% Completed | 24.01 ss
# [########################################] | 100% Completed | 20.97 ss
# [########################################] | 100% Completed | 15.80 ss
# [########################################] | 100% Completed | 20.08 ss
# [########################################] | 100% Completed | 19.85 ss
# [########################################] | 100% Completed | 19.74 ss
# [########################################] | 100% Completed | 9.33 sms
# [########################################] | 100% Completed | 14.18 ss
# [########################################] | 100% Completed | 23.44 ss
# [########################################] | 100% Completed | 27.10 ss
# [########################################] | 100% Completed | 21.41 ss
# [########################################] | 100% Completed | 16.31 ss
# [########################################] | 100% Completed | 10.76 ss
# Z-cropping enabled: False
# Threshold: 0.005 (empty slices below 0.5% of max intensity)
# [########                                ] | 20% Completed | 42.29 ss
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 110
#     107 print(f"Threshold: {cfg.Z_CROP_THRESHOLD} (empty slices below {cfg.Z_CROP_THRESHOLD*100}% of max intensity)")
#     109 # Now when you call st.fuse_and_export(), add the parameters:
# --> 110 st.fuse_and_export(
#     111     msims,
#     112     out_dir,
#     113     export_tiff=True,
#     114     crop_z_black_frames=cfg.CROP_Z_BLACK_FRAMES,
#     115     z_crop_threshold=cfg.Z_CROP_THRESHOLD
#     116 )
#     117 # st.fuse_and_export(msims, out_dir, export_tiff=False) #old one
#     118 print(f"→ Written to {out_dir}")
#
# File D:\GITHUB_SOFTWARE\karyosight\karyosight\src\karyosight\stitcher.py:704, in Stitcher.fuse_and_export(self, msims, out_folder, export_tiff, crop_z_black_frames, z_crop_threshold)
#     702 # Save to zarr
#     703 with dask.diagnostics.ProgressBar():
# --> 704     ngff_utils.write_sim_to_ome_zarr(fused, str(zarr_out), overwrite=True)
#     706 # Optionally save to TIFF
#     707 if export_tiff:
#
# File d:\GITHUB_SOFTWARE\mamba_envs\karyosight-env\Lib\site-packages\multiview_stitcher\ngff_utils.py:260, in write_sim_to_ome_zarr(sim, output_zarr_url, downscale_factors_per_spatial_dim, overwrite)
#     248     output_zarr_arr = zarr.open(
#     249         f"{output_zarr_url}/0",
#     250         shape=sim.data.shape,
#    (...)    256         mode="w",
#     257     )
#     259     # Write the lowest resolution
# --> 260     sim.data = sim.data.to_zarr(
#     261         output_zarr_arr,
#     262         overwrite=True,
#     263         dimension_separator="/",
#     264         return_stored=True,
#     265         compute=True,
#     266     )
#     267     top_level_exists = False
#     269 coordtfs = [
#     270     [
#     271         {
#    (...)    290     for res_level in range(n_resolutions)
#     291 ]
#
# File d:\GITHUB_SOFTWARE\mamba_envs\karyosight-env\Lib\site-packages\dask\array\core.py:3036, in Array.to_zarr(self, *args, **kwargs)
#    3025 def to_zarr(self, *args, **kwargs):
#    3026     """Save array to the zarr storage format
#    3027
#    3028     See https://zarr.readthedocs.io for details about the format.
#    (...)   3034     dask.array.to_zarr : equivalent function
#    3035     """
# -> 3036     return to_zarr(self, *args, **kwargs)
#
# File d:\GITHUB_SOFTWARE\mamba_envs\karyosight-env\Lib\site-packages\dask\array\core.py:3910, in to_zarr(arr, url, component, storage_options, overwrite, region, compute, return_stored, **kwargs)
#    3908         arr = arr.rechunk(chunks)
#    3909         regions = [region]
# -> 3910     return arr.store(
#    3911         z, lock=False, regions=regions, compute=compute, return_stored=return_stored
#    3912     )
#    3913 else:
#    3914     if not _check_regular_chunks(arr.chunks):
#    3915         # We almost certainly get here because auto chunking has been used
#    3916         # on irregular chunks. The max will then be smaller than auto, so using
#    3917         # max is a safe choice
#
# File d:\GITHUB_SOFTWARE\mamba_envs\karyosight-env\Lib\site-packages\dask\array\core.py:1814, in Array.store(self, target, **kwargs)
#    1812 @wraps(store)
#    1813 def store(self, target, **kwargs):
# -> 1814     r = store([self], [target], **kwargs)
#    1816     if kwargs.get("return_stored", False):
#    1817         r = r[0]
#
# File d:\GITHUB_SOFTWARE\mamba_envs\karyosight-env\Lib\site-packages\dask\array\core.py:1245, in store(***failed resolving arguments***)
#    1243 if compute:
#    1244     store_dlyds = [Delayed(k, store_dsk, layer=k[0]) for k in map_keys]
# -> 1245     store_dlyds = persist(*store_dlyds, **kwargs)
#    1246     store_dsk_2 = HighLevelGraph.merge(*[e.dask for e in store_dlyds])
#    1247     load_store_dsk = retrieve_from_ooc(map_keys, store_dsk, store_dsk_2)
#
# File d:\GITHUB_SOFTWARE\mamba_envs\karyosight-env\Lib\site-packages\dask\base.py:1001, in persist(traverse, optimize_graph, scheduler, *args, **kwargs)
#     998     postpersists.append((rebuild, a_keys, state))
#    1000 with shorten_traceback():
# -> 1001     results = schedule(dsk, keys, **kwargs)
#    1003 d = dict(zip(keys, results))
#    1004 results2 = [r({k: d[k] for k in ks}, *s) for r, ks, s in postpersists]
#
# File d:\GITHUB_SOFTWARE\mamba_envs\karyosight-env\Lib\site-packages\dask\diagnostics\progress.py:106, in ProgressBar._pretask(self, key, dsk, state)
#     104 self._state = state
#     105 if self._file is not None:
# --> 106     self._file.flush()
#
# File d:\GITHUB_SOFTWARE\mamba_envs\karyosight-env\Lib\site-packages\ipykernel\iostream.py:609, in OutStream.flush(self)
#     607     self.pub_thread.schedule(evt.set)
#     608     # and give a timeout to avoid
# --> 609     if not evt.wait(self.flush_timeout):
#     610         # write directly to __stderr__ instead of warning because
#     611         # if this is happening sys.stderr may be the problem.
#     612         print("IOStream.flush timed out", file=sys.__stderr__)
#     613 else:
#
# File d:\GITHUB_SOFTWARE\mamba_envs\karyosight-env\Lib\threading.py:655, in Event.wait(self, timeout)
#     653 signaled = self._flag
#     654 if not signaled:
# --> 655     signaled = self._cond.wait(timeout)
#     656 return signaled
#
# File d:\GITHUB_SOFTWARE\mamba_envs\karyosight-env\Lib\threading.py:359, in Condition.wait(self, timeout)
#     357 else:
#     358     if timeout > 0:
# --> 359         gotit = waiter.acquire(True, timeout)
#     360     else:
#     361         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %% [markdown]
# Cropper

# %%
# -----------------------------------------------------------------------------
# Production Cropping: Peak Mode + Black Frame Removal for All Zarrs
# -----------------------------------------------------------------------------
from pathlib import Path
from karyosight.cropper import Cropper
import karyosight.config as cfg
import numpy as np

# USER SETTINGS
z_slices_around_peak = 14        # Adjust this: slices above/below peak (total = 2*this + 1)
black_frame_threshold = 0.01     # 1% of max intensity threshold
min_z_slices = 20                 # Minimum slices to keep after cleaning

print(f"🎯 Peak Mode Settings: {z_slices_around_peak} slices around peak = {2*z_slices_around_peak + 1} total")
print(f"🧹 Black frame threshold: {black_frame_threshold} ({black_frame_threshold*100}% of max intensity)")
print(f"📏 Minimum slices: {min_z_slices}")

pad_pct = 0.6
pad_step = 0.05

# instantiate your cropper  
cp = Cropper(  
    stitched_dir=Path(cfg.STITCHED_DIR),  
    cropped_dir=Path(cfg.CROPPED_DIR),  
    low_level=1,  
    high_level=0,  
    scheduler='threads',  
)

overview_root = Path(cfg.CROPPED_DIR)
stitched_root = Path(cfg.STITCHED_DIR)

# find all .zarr files under stitched/, but only keep the true "subgrid" ones
all_zarrs = [
    p for p in stitched_root.rglob("*.zarr")
    # parent folder name must equal the zarr filename (minus .zarr)
    if p.parent.name == p.stem
]

if not all_zarrs:
    print("⚠️  No subgrid zarrs found (parent.name != stem)!")
else:
    print(f"\n📂 Processing {len(all_zarrs)} zarr files...")
    
    for i, zarr_path in enumerate(sorted(all_zarrs)):
        # 1) grab the Condition_* parent
        cond_name = next(
            p.name
            for p in zarr_path.parents
            if p.name.startswith(cfg.CONDITION_PREF)
        )
        # 2) subgrid_id is simply the parent folder
        subgrid_id = zarr_path.parent.name

        print(f"\n[{i+1}/{len(all_zarrs)}] {cond_name} / {subgrid_id}")

        # extract ROIs (no visualization for speed)
        rois = cp.extract_rois_from_level(
            zarr_path,
            pad_pct=pad_pct,
            pad_step=pad_step,
            visualize=False,  # Skip visualization for speed
            verbose=False     # Reduce verbosity
        )
        
        print(f"   🔎 Found {len(rois)} ROIs")

        # Peak Mode + Aggressive Black Frame Removal
        try:
            out_path = cp.bundle_and_save_rois(
                zarr_path, 
                rois,
                z_extraction_mode='peak',
                z_slices_around_peak=z_slices_around_peak,
                intensity_channel=0,              # Use CH1 for peak detection
                remove_black_frames=True,
                black_frame_threshold=black_frame_threshold,
                black_frame_method='intensity_threshold',
                min_z_slices=min_z_slices
            )
            print(f"   ✅ Saved: {out_path.name}")
            
        except Exception as e:
            print(f"   ❌ Error processing {subgrid_id}: {e}")
            continue

print(f"\n🏁 Processing complete! All zarr files processed with peak mode + black frame removal.")
print(f"💡 Settings used: {2*z_slices_around_peak + 1} z-slices, {black_frame_threshold*100}% threshold")

# %% [markdown]
# Visualization

# %%
# Import the new visualization class
from karyosight.visualization import OrganoidVisualizer
import karyosight.config as cfg

# Initialize the visualizer
visualizer = OrganoidVisualizer(cropped_dir=cfg.CROPPED_DIR)

# 1. Count organoids per condition
print("=== Organoid Counts ===")
counts = visualizer.count_organoids_per_condition()
print("\nSummary:")
for condition, count in counts.items():
    print(f"  {condition}: {count} organoids")

# %%
# 2. Create visualizations for a specific condition and channel
# Example: Visualize CH1 (channel 0) for first condition, sampling 12 organoids

if counts:
    # Get the first condition with organoids
    first_condition = next(cond for cond, count in counts.items() if count > 0)
    
    print(f"\n=== Creating visualization for {first_condition} ===")
    
    # Create grid visualization for CH1 (index 0)
    saved_path = visualizer.create_organoid_grid(
        condition=first_condition,
        channel=0,  # CH1
        level=0,   # Use pyramid level 1 (lower resolution)
        sample_count=8,  # Sample 12 organoids, or None for all
        auto_scale_method='individual',  # 'individual' or 'global'
        save_png=True,
        show_plot=True
    )

# %%
# 3. Create visualizations for all conditions at once
print("\n=== Creating visualizations for all conditions ===")

# Create grid visualizations for all conditions, CH2 (index 1), sampling 8 organoids each
saved_paths = visualizer.create_all_conditions_grid(
    channel=0,  # CH2
    level=0,
    sample_count=8,  # Sample 8 organoids per condition
    auto_scale_method='global',  # Use global scaling for comparison across conditions
    save_png=True,
    show_plot=True
)

print(f"\nSaved {len(saved_paths)} visualization files")

# %%
# 4. Create a channel comparison for a specific organoid
# This shows all 6 channels for a single organoid side-by-side

if counts:
    print("\n=== Creating channel comparison ===")
    
    # Compare all channels for organoid #0 in the first condition
    channel_comparison_path = visualizer.create_channel_comparison(
        condition=first_condition,
        organoid_idx=0,  # First organoid
        level=0,
        channels=None,  # None = all 6 channels, or specify [0,1,2] for specific channels
        auto_scale_method='individual',  # Scale each channel independently
        save_png=True,
        show_plot=True
    )

# %%
for organoididx in range(list(counts.values())[0]):  # Get first value from dict and convert to range
    # Compare all channels for organoid #0 in the first condition
    channel_comparison_path = visualizer.create_channel_comparison(
        condition=first_condition,
        organoid_idx=organoididx,  # First organoid
        level=0,
        channels=None,  # None = all 6 channels, or specify [0,1,2] for specific channels
        auto_scale_method='individual',  # Scale each channel independently
        save_png=True,
        show_plot=True
    )
